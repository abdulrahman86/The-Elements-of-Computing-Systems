# %%
code = "/home/coykto/PycharmProjects/Rect.hack"
code_to_check = "/home/coykto/PycharmProjects/RectRESULT.hack"

code_lines = []
check_lines = []
with open(code) as source:
    code_lines = source.readlines()

with open(code_to_check) as source:
    check_lines = source.readlines()
    
print("Rect.hack", "Result")
for i in range(len(code_lines)):
    print("{i:2d} {code}   {result}".format(code=code_lines[i], result=check_lines[i], i=i+1))
# Out:
# Rect.hack Result
#  1 0000000000000000
#    0000000000000000
#
#  2 1111110000010000
#    1111110000010000
#
#  3 0000000000010111
#    0000000000010111
#
#  4 1110001100000110
#    1110001100000110
#
#  5 0000000000010000
#    0000000000010000
#
#  6 1110001100001000
#    1110001100001000
#
#  7 0100000000000000
#    0100000000000000
#
#  8 1110110000010000
#    1110110000010000
#
#  9 0000000000010001
#    0000000000010001
#
# 10 1110001100001000
#    1110001100001000
#
# 11 0000000000010001
#    0000000000010001
#
# 12 1111110000100000
#    1111110000100000
#
# 13 1110111010001000
#    1110111010001000
#
# 14 0000000000010001
#    0000000000010001
#
# 15 1111110000010000
#    1111110000010000
#
# 16 0000000000100000
#    0000000000100000
#
# 17 1110000010010000
#    1110000010010000
#
# 18 0000000000010001
#    0000000000010001
#
# 19 1110001100001000
#    1110001100001000
#
# 20 0000000000010000
#    0000000000010000
#
# 21 1111110010011000
#    1111110010011000
#
# 22 0000000000001010
#    0000000000001010
#
# 23 1110001100000001
#    1110001100000001
#
# 24 0000000000010111
#    0000000000010111
#
# 25 1110101010000111
#    1110101010000111
